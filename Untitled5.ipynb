# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanchita3005/SANCHITA-practice-1/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

conn = sqlite3.connect("bus.db")
cur = conn.cursor()

cur.execute("""
CREATE TABLE IF NOT EXISTS booking(
id INTEGER PRIMARY KEY,
name TEXT,
bus_no TEXT,
seat_no INTEGER)
""")

name = input("Enter Passenger Name: ")
bus = input("Enter Bus Number: ")
seat = int(input("Enter Seat Number: "))

cur.execute("INSERT INTO booking(name,bus_no,seat_no) VALUES(?,?,?)",
            (name,bus,seat))

conn.commit()
print("Ticket Booked Successfully!")

conn.close()
# Out:
# Enter Passenger Name: Sanchita
# Enter Bus Number: 45
# Enter Seat Number: 105
# Ticket Booked Successfully!
