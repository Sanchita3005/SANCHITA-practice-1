# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanchita3005/SANCHITA-practice-1/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#isalnum

#A-Z, a-z, 0-1 consist in string. If any punctuation marks, characters are present then it gives output false


a = "Welcometopython"
print(a.isalnum())
# Out:
# True

# %%
#If space is present

a = "Hello world"
print(a.isalnum())
# Out:
# False
